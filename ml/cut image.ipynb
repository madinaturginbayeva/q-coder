# %%
import cv2

# %%
import numpy as np

# %%
image= cv2.imread('aaa.jpg')

# %%
import cv2

cvim2disp = cv2.imread('aaa.jpg')
cv2.imshow('img', cvim2disp)
while(True):
    k = cv2.waitKey(33)
    if k == -1:  # if no key was pressed, -1 is returned
        continue
    else:
        break
cv2.destroyWindow('img')

# %%
pip install pic_cut

# %%
import pic_cut
file_list = pic_cut.cut('aaa.jpg')

# %%
window_name = 'image'

# %%
file_list
# Out:
# <generator object cut at 0x1060464d0>

# %%
pip install image
# Out:
# Collecting image
#   Downloading https://files.pythonhosted.org/packages/9d/a7/70108b13af991e49deb0cbfc717cae57614eae29ff2d3fa79532eead28cb/image-1.5.28.tar.gz
# Requirement already satisfied: pillow in /Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages (from image) (6.2.0)
# Collecting django (from image)
#   Downloading https://files.pythonhosted.org/packages/12/68/8c125da33aaf0942add5095a7a2a8e064b3812d598e9fb5aca9957872d71/Django-3.0.4-py3-none-any.whl (7.5MB)
#      |████████████████████████████████| 7.5MB 24kB/s eta 0:00:012
# Collecting sqlparse>=0.2.2 (from django->image)
#   Downloading https://files.pythonhosted.org/packages/85/ee/6e821932f413a5c4b76be9c5936e313e4fc626b33f16e027866e1d60f588/sqlparse-0.3.1-py2.py3-none-any.whl (40kB)
#      |████████████████████████████████| 40kB 13kB/s eta 0:00:013
# Collecting asgiref~=3.2 (from django->image)
#   Downloading https://files.pythonhosted.org/packages/68/00/25013f7310a56d17e1ab6fd885d5c1f216b7123b550d295c93f8e29d372a/asgiref-3.2.7-py2.py3-none-any.whl
# Requirement already satisfied: pytz in /Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages (from django->image) (2019.3)
# Building wheels for collected packages: image
#   Building wheel for image (setup.py) ... done
#   Created wheel for image: filename=image-1.5.28-py2.py3-none-any.whl size=19517 sha256=ec6a2a67b2fa92a4a8caa27c11136bfc11598a79090ac3f8c76416025d09f302
#   Stored in directory: /Users/ulzhanakmurat/Library/Caches/pip/wheels/17/c3/b2/0435a955f6cf071224a9b226071e9798dc2289dd9b37115fc6
# Successfully built image
# Installing collected packages: sqlparse, asgiref, django, image
# Successfully installed asgiref-3.2.7 django-3.0.4 image-1.5.28 sqlparse-0.3.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Image
# Out:
# Requirement already satisfied: Image in /Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages (1.5.28)
# Requirement already satisfied: django in /Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages (from Image) (3.0.4)
# Requirement already satisfied: pillow in /Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages (from Image) (6.2.0)
# Requirement already satisfied: pytz in /Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages (from django->Image) (2019.3)
# Requirement already satisfied: sqlparse>=0.2.2 in /Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages (from django->Image) (0.3.1)
# Requirement already satisfied: asgiref~=3.2 in /Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages (from django->Image) (3.2.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wand.image import Image

input_path = "png2/student81.pdf"
output_name = "png2/student81.png"
source = Image(filename=input_path, resolution=300, width=2200)
images = source.sequence
for i in range(len(images)):
    Image(images[0]).save(filename=output_name.format(i))

# %%
pip install imagemagick
# Out:
# Collecting imagemagick
#   ERROR: Could not find a version that satisfies the requirement imagemagick (from versions: none)
# ERROR: No matching distribution found for imagemagick
# Note: you may need to restart the kernel to use updated packages.

# %%
import os

from PIL import Image

# Crops the image and saves it as "new_filename"
def crop_image(img, crop_area, new_filename):
    cropped_image = img.crop(crop_area)
    ccropped_image.save(new_filename)

# The x, y coordinates of the areas to be cropped. (x1, y1, x2, y2)

for i in range(1):
    
    crop_areas = [(0, 0, 920, 276),(0, 0, 326,100)] #cut zadachi
    image_name = 'check'+ str(i) + '.png'
    img = Image.open(image_name)

        # Loops through the "crop_areas" list and crops the image based on the coordinates in the list
    for i, crop_area in enumerate(crop_areas):

        if(i==0):
            filename = os.path.splitext(image_name)[0]
            ext = os.path.splitext(image_name)[1]
            new_filename = 'tensorflow/'+filename + '_name' + str(i) + ext #tanserflow - name of the second folder
            crop_image(img, crop_area, new_filename)
        if(i==1):
            filename = os.path.splitext(image_name)[0]
            ext = os.path.splitext(image_name)[1]
            new_filename = 'tensorflow/'+filename + '_name' + str(i) + ext  #tanserflow - name of the second folder
            crop_image(img, crop_area, new_filename)

# %%
import cv2

img_cv = cv2.imread('png2/student81.png')

# By default OpenCV stores images in BGR format and since pytesseract assumes RGB format,
# we need to convert from BGR to RGB format/mode:
img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
print(pytesseract.image_to_string(img_rgb))
# Out:
# 3]
# NAME & SURNAME : Yelewbes nov Bime nde ID: \BOl\O AZ
#
# Q1: User enters your index, phe page by the following URL: Index. php?x=7&y=982=6
# PHP file should output the maximum numbers of 3 numbers
#
#
#
#
#
#
# @2\se
#
#
#
#
#
#
#
#
#
#
#
#
#
# echo
# O % $2) R .
# , echo "ers N\nower is
#
#
#
#
#
# Q2: Output even numbers less than 1000:
# <7 prP
#
#
#
#
#
# Sor C$l=0 ‘ $i < \000)} 4p +=25§
# 4 echs ty \ ‘S
# wy g
# 3: Write code into the left column, so that result will be like in the right column
# <?phoe
#
#
#
# $lessons = ['Algebra’,"Calculus’,"Uava’)];
# /* Enter your code below */
#
# Foreach (lessons as le sson ) S
#
# echo it
#
#
#
#
#
# <div><img src="image.png /><strong>Algebra</strong></div>
# <div><strong>Cal culus</strong><img src="image.ong’/></div>
# <div><img src="image.eng"/><strong>Java</strong></div>
#
#
#
#
# 2 pr Pp
# ’ (A is
# 03 ~ setcookie £ Loken
#
# Q5: Write SQL query to get all data from table employees where id is more than 50, and output it on
# page
#
# Squec= select Bek td >be Seo table >
#
# Seceach CE query as $q)> ?
# etho Nh gy ff
#
# A
#
#
#
# > @ 3»
# <div> CMR $te =. Yn ee. PrL, ‘> ye Me seats EN viernes mf el ste
#
# €av> <r oh ee Vesson Sf Ay </ S74 rong > _¢ 8 -@ eee F . SAivea
# asus vw u... engl > wine, heres ae KR/sot cong”> s=/divJ

# %%
import pytesseract

# %%
print(img)
# Out:
# None

# %%
pip install TextExtract
# Out:
# Requirement already satisfied: TextExtract in /Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from TextExtractApi.TextExtract import TextExtractFunctions  
  

  
#Get list of result with matches results  
finalresult,scaled_results=TextExtractFunctions.image_to_string_matched("check0.png",expected_text='Menu',all_results=True)
# Out:
# Exception in thread Thread-7:
# Traceback (most recent call last):
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 116, in tesseract_worker
#     self.tes_extract_thread(x)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 105, in tes_extract_thread
#     result_text_thread = tess_img_to_string(self.image_path, scaling_factor='NA', lang=self.lang)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 54, in tess_img_to_string
#     stdout, stderr, return_code, pid = run_cmd(cmd)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 27, in run_cmd
#     process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/subprocess.py", line 775, in __init__
#     restore_signals, start_new_session)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/subprocess.py", line 1522, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# OSError: [Errno 8] Exec format error: '/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/tesseract.exe'
#
# Exception in thread Thread-4:
# Traceback (most recent call last):
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 116, in tesseract_worker
#     self.tes_extract_thread(x)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 101, in tes_extract_thread
#     result_text_thread = tess_img_to_string(temp_image_name, scaling_factor, lang=self.lang)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 54, in tess_img_to_string
#     stdout, stderr, return_code, pid = run_cmd(cmd)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 27, in run_cmd
#     process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/subprocess.py", line 775, in __init__
#     restore_signals, start_new_session)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/subprocess.py", line 1522, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# OSError: [Errno 8] Exec format error: '/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/tesseract.exe'
#
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 116, in tesseract_worker
#     self.tes_extract_thread(x)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 101, in tes_extract_thread
#     result_text_thread = tess_img_to_string(temp_image_name, scaling_factor, lang=self.lang)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 54, in tess_img_to_string
#     stdout, stderr, return_code, pid = run_cmd(cmd)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 27, in run_cmd
#     process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/subprocess.py", line 775, in __init__
#     restore_signals, start_new_session)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/subprocess.py", line 1522, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# OSError: [Errno 8] Exec format error: '/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/tesseract.exe'
#
# Exception in thread Thread-8:
# Traceback (most recent call last):
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 116, in tesseract_worker
#     self.tes_extract_thread(x)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 101, in tes_extract_thread
#     result_text_thread = tess_img_to_string(temp_image_name, scaling_factor, lang=self.lang)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 54, in tess_img_to_string
#     stdout, stderr, return_code, pid = run_cmd(cmd)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 27, in run_cmd
#     process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/subprocess.py", line 775, in __init__
#     restore_signals, start_new_session)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/subprocess.py", line 1522, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# OSError: [Errno 8] Exec format error: '/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/tesseract.exe'
#
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 116, in tesseract_worker
#     self.tes_extract_thread(x)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 101, in tes_extract_thread
#     result_text_thread = tess_img_to_string(temp_image_name, scaling_factor, lang=self.lang)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 54, in tess_img_to_string
#     stdout, stderr, return_code, pid = run_cmd(cmd)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py", line 27, in run_cmd
#     process = subprocess.Popen(cmd, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/subprocess.py", line 775, in __init__
#     restore_signals, start_new_session)
#   File "/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/subprocess.py", line 1522, in _execute_child
#     raise child_exception_type(errno_num, err_msg, err_filename)
# OSError: [Errno 8] Exec format error: '/Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/tesseract.exe'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-36-6962342919a8> in <module>
#       4
#       5 #Get list of result with matches results
# ----> 6 finalresult,scaled_results=TextExtractFunctions.image_to_string_matched("check0.png",expected_text='Menu',all_results=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py in image_to_string_matched(cls, image_path, expected_text, lang, all_results)
#     314         ocr_object = TextExtract(lang)
#     315         if os.path.isfile(os.path.abspath(image_path)):
# --> 316             final_text, highest_per, result_text = ocr_object.image_to_string(image_path, expected_text)
#     317             result = [final_text, highest_per]
#     318             if result[1] <= 0.0:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/TextExtractApi/TextExtract.py in image_to_string(self, image_path, expected_text)
#     147         for x in self.scaling_factors:
#     148             self.OCR_Thread.put(x)
# --> 149         self.OCR_Thread.join()
#     150
#     151         for _ in threads:
#
# ~/opt/anaconda3/lib/python3.7/queue.py in join(self)
#      87         with self.all_tasks_done:
#      88             while self.unfinished_tasks:
# ---> 89                 self.all_tasks_done.wait()
#      90
#      91     def qsize(self):
#
# ~/opt/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
from PIL import Image
import pytesseract
import os
import sys
import cv2
import numpy as np



####################################################################################
########################All image customization methods#############################
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)
 
#thresholding
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

#dilation
def dilate(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.dilate(image, kernel, iterations = 1)
    
#erosion
def erode(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.erode(image, kernel, iterations = 1)

#opening - erosion followed by dilation
def opening(image):
    kernel = np.ones((5,5),np.uint8)
    return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

#canny edge detection
def canny(image):
    return cv2.Canny(image, 100, 200)

#skew correction
def deskew(image):
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

#template matching
def match_template(image, template):
    return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)


########################All image customization methods#############################    
#####################Check for more customization choices at########################
#####################https://nanonets.com/blog/ocr-with-tesseract/##################
####################################################################################

def get_text_from_image(image_path):
    text = ""
    try:
        img = cv2.imread(image_path)
        # text = pytesseract.image_to_string(Image.open(image_path))
        img = get_grayscale(img)
        # img = opening(img)
        img = canny(img)
        text = pytesseract.image_to_string(img)
    except Exception as e:
        print("ERROR: Failed to read file - {0}".format(image_path))
        print(e)
    return text
    

def extract_text_from_image(image_path):
    text = get_text_from_image(image_path)
    print("Text extracted from image {0}".format(image_path))
    print("==========================BEGIN=========================")
    print(text)
    print("===========================END==========================")


def get_all_images_from_directory(source_dir):
    image_files = []
    images_dir = os.listdir(source_dir)
    for image_file in images_dir:
        image_files.append(image_file)
    return image_files


def main():
    # images_dir = os.path.join(os.getcwd(), 'images')
    # images_dir = "/Users/sriramk/Downloads/images"
    # all_image_files = get_all_images_from_directory(images_dir)
    #
    # for image_file in all_image_files:
    #     extract_text_from_image(os.path.join(images_dir, image_file))
    extract_text_from_image('check0.png')

if __name__ == "__main__":
    main()
# Out:
# Text extracted from image check0.png
# ==========================BEGIN=========================
# Et
# Skea Eel CaP ee Re (ae
#
# ee ee epee al tate eae
# Fae Titre hee arena eee ee
#
# cee TT) re)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ary) eee
# 5 Peete eee ts
#
# (Sacre ee NO
#
# Toe
# ARO ters,
# Pa nee
#
# ee
#
# PAS Yoo eT se eo co odes ee eo tea] OL es
#
# cy [ence iar Meera ed
# ee cna)
#
#
#
# etd
# Se aE
# cae
#
#
#
#
#
#
#
#
#
#
#
# Seguin acter ame ited
# er Cn aca eg
# Se a ae ee
#
# (eas
# [ifexeusclinue teeta)
# ror 7
# ee a a a aS
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# a", Seakton worielie wer anecalea cat]
#
#
#
#
#
#
#
#
#
#
#
#
#
# us
#
#
#
#
#
#
#
#
#
#
#
#
#
# ae Tor SS er EROS)
# B59
# Mee eee bate ed ae)
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# a
#
# CA he ay Se
#
#
#
# i) oo Cor he)
# a tne
# By
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Decca ae ety aa ones
# aie coreg Perey a , BAleD
# Cr ee oi peer een | Pees eee
# ===========================END==========================

# %%
ls
# Out:
# 01.jpg
# 5de75c8f40860.png
# Ahern_S-lyubovyu-Rozi.506728.fb2.epub
# Application-Forms-For-2020-International-Admissions-3.pages*
# Application-forms 4.pages*
# Application-forms 5.pages*
# CSS 324 Introduction to Machine Learning Lecture 0.pptx.cpgz
# Forma-zayavki-ENG 2.xlsx
# Forma-zayavki-ENG.xlsx
# Forma-zayavki-ENG.xlsx 2.cpgz
# Forma-zayavki-ENG.xlsx 3.cpgz
# Forma-zayavki-ENG.xlsx.cpgz
# Freebie Template 1 - Car Repair and Doggie Daycare by June Parent.dms
# Gilbert_Est-molitsya-lyubit.156602.fb2.epub
# Group 2.png
# Group 6.jpg
# Group 7.jpg
# Group 8.jpg
# Logistic Regression Model (1).ipynb
# Path to store the CSV file\File name.csv
# RnnChatPrediction-master/
# Screen Recording 2020-04-01 at 21.07.56.mov
# Screen Recording 2020-04-01 at 21.30.10.mov
# Screen Recording 2020-04-01 at 21.31.39.mov
# Screen Recording 2020-04-01 at 21.32.22.mov
# Screen Recording 2020-04-01 at 21.32.57.mov
# Screen Recording 2020-04-01 at 21.33.39.mov
# Screen Recording 2020-04-01 at 21.37.40.mov
# Screen Recording 2020-04-01 at 21.38.19.mov
# Screen Recording 2020-04-01 at 21.40.47.mov
# Screen Recording 2020-04-01 at 21.42.14.mov
# Screen Shot 2019-12-05 at 14.07.20.png
# Screen Shot 2019-12-05 at 14.07.47.png
# Screen Shot 2019-12-05 at 14.07.52.png
# Screen Shot 2019-12-05 at 14.08.01.png
# Screen Shot 2019-12-05 at 14.08.06.png
# Screen Shot 2019-12-05 at 14.34.09.png
# Screen Shot 2019-12-05 at 14.38.15.png
# Screen Shot 2019-12-05 at 14.38.24.png
# Screen Shot 2019-12-05 at 14.38.28.png
# Screen Shot 2019-12-05 at 14.39.40.png
# Screen Shot 2019-12-05 at 14.41.14.png
# Screen Shot 2019-12-06 at 17.29.24.png
# Screen Shot 2019-12-06 at 17.31.19.png
# Screen Shot 2019-12-06 at 17.32.08.png
# Screen Shot 2019-12-07 at 15.38.02.png
# Screen Shot 2019-12-10 at 00.41.15.png
# Screen Shot 2019-12-11 at 11.39.45.png
# Screen Shot 2019-12-15 at 13.36.30.png
# Screen Shot 2019-12-18 at 18.24.55.png
# Screen Shot 2019-12-18 at 18.25.16.png
# Screen Shot 2019-12-18 at 18.25.45.png
# Screen Shot 2019-12-18 at 19.24.55.png
# Screen Shot 2019-12-18 at 21.21.10.png
# Screen Shot 2019-12-18 at 21.40.15.png
# Screen Shot 2019-12-18 at 21.46.28.png
# Screen Shot 2019-12-18 at 22.03.00.png
# Screen Shot 2020-01-09 at 14.36.31.png
# Screen Shot 2020-01-09 at 14.36.47.png
# September'2015.xlsx.cpgz
# September2015.xlsx
# TensorFlow-Object-Detection-API-Tutorial-Train-Multiple-Objects-Windows-10-master/
# Ulzhan-2.pdf
# Ulzhan.pdf
# UlzhanAkmurat_CV 2.pdf
# UlzhanAkmurat_CV.pdf
# Ulzhan_Akmurat.pdf
# Ulzhan_akmurat_UNIST.pdf
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# aaa.jpg
# aaa_cropped0.jpg
# bazel-1.1.0-installer-darwin-x86_64.sh*
# bazelisk/
# bazelisk-master.zip
# check0.png
# check_name0.png
# check_name1.png
# color3.jpg
# color4.jpg
# color6.jpg
# computer vision/
# cut image.ipynb
# cutting_image.mp4
# data.xlsx
# data1.csv
# data2.csv
# data3.csv
# dbzb/
# face_recognition/
# jaxart/
# list.csv
# m1.csv
# m2.csv
# m3.csv
# m4.csv
# m5.csv
# machine learmimg /
# nurse_parse_region.ipynb
# out.pdf
# out.txt
# pytesseract/
# recommender-systems-master/
# temp_1.png
# temp_2.png
# temp_4.png
# temp_8.png
# temp_only_text.png
# tensorflow/
# tensorflow-master.zip*
# tensorflow1/
# untitled folder/
# untitled folder 2/
# untitled folder 3/
# Пикины-Копбаева.docx
# Предварительный просмотр файла 11.jpg11.jpg111 KB.webloc

# %%
import os
import os.path
import pytesseract
import argparse
import cv2
import time
from pdf2image import convert_from_path
from PyPDF2 import PdfFileReader, PdfFileWriter
from pdf2image.exceptions import (
 PDFInfoNotInstalledError,
 PDFPageCountError,
 PDFSyntaxError
)
from PIL import Image

start_time = time.time()


def pdfToPng():
    path = 'diplCropToPng/pngFormat'
    paths = 'diplCropToPng/Tesseract'
    try:
        os.mkdir(path, paths)
    except OSError:
        print("Creation of the directory %s failed" % path)
    else:
        print("Successfully created the directory %s " % path)
    images = convert_from_path('diploma.pdf')

    for i, image in enumerate(images):
        fname = 'image'+str(i+1)+'.png'
        image.save('diplCropToPng/pngFormat/'+fname, "PNG")

# Crops the image and saves it as "new_filename"
def crop_image(img, crop_area, new_filename):
    cropped_image = img.crop(crop_area)
    cropped_image.save(new_filename)

        #image_name = '/Users/turginbaevamadina/PycharmProjects/diploma/diplCropToPng/image1.png'
def check():  # The x, y coordinates of the areas to be cropped. (left, upper, right, lower)
    for i in range(83):
        path = 'diplCropToPng/image' + str(i + 1)
        try:
            os.mkdir(path)
        except OSError:
            print("Creation of the directory %s failed" % path)
        else:
            print("Successfully created the directory %s " % path)


    for i in range(1):
        crop_areas = [(0, 0, 920, 276), (1000, 100, 1600,270), (0, 280, 1650, 380), (0, 370, 1650, 530), (0, 520, 1650, 560)
            , (0, 550, 1650, 750), (0, 740, 1650, 805), (0, 800, 1650, 1300), (0, 1290, 1650, 1410), (0, 1400, 1650, 1580)
            , (0, 1580, 1655, 1730), (0, 1730, 1650, 2080)]

        for i in range(83):
            image_name = 'diplCropToPng/pngFormat/image' + str(i+1) +'.png'
            img = Image.open(image_name)
            image_name2 = 'diplCropToPng/image' + str(i + 1) + '.png'

            # Loops through the "crop_areas" list and crops the image based on the coordinates in the list
            for i, crop_area in enumerate(crop_areas):
                ...
                #if (i == 0):
                #   filename = os.path.splitext(image_name)[0]
                #   ext = os.path.splitext(image_name)[1]
                #   new_filename = filename +'/tensorflow'+ '_name' + str(
                #       i) + ext  # tanserflow - name of the second folder
                #   crop_image(img, crop_area, new_filename)
                #if (i == 1):
                #    filename = os.path.splitext(image_name)[0]
                #   ext = os.path.splitext(image_name)[1]
                #   new_filename = filename + '/tensorflow'+ '_name' + str(
                #       i) + ext  # tanserflow - name of the second folder
                #   crop_image(img, crop_area, new_filename)
                if (i == 3):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        1) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 5):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        2) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 7):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        3) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 9):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        4) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 11):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        5) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)


def tesseract():
    #reader = PdfFileReader('/Users/turginbaevamadina/Downloads/diploma.pdf', 'r')
    #sum = reader.getNumPages()
    img_cv = cv2.imread(r'tensorflow_name2.png')

    # By default OpenCV stores images in BGR format and since pytesseract assumes RGB format,
    # we need to convert from BGR to RGB format/mode:
    img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
    print(pytesseract.image_to_string(img_rgb))
    # OR
    img_rgb = Image.frombytes('RGB', img_cv.shape[:2], img_cv, 'raw', 'BGR', 0, 0)
    print(pytesseract.image_to_string(img_rgb))



pdfToPng()
check()
#tesseract()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-b7de549f0e0c> in <module>
#     121
#     122
# --> 123 pdfToPng()
#     124 check()
#     125 #tesseract()
#
# <ipython-input-48-b7de549f0e0c> in pdfToPng()
#      21     paths = 'diplCropToPng/Tesseract'
#      22     try:
# ---> 23         os.mkdir(path, paths)
#      24     except OSError:
#      25         print("Creation of the directory %s failed" % path)
#
# TypeError: an integer is required (got type str)

# %%
pip install PyPDF2
# Out:
# Requirement already satisfied: PyPDF2 in /Users/ulzhanakmurat/opt/anaconda3/lib/python3.7/site-packages (1.26.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
convert_from_path.(open('your_path/example.pdf').read()
# Out:
# <function pdf2image.pdf2image.convert_from_path(pdf_path, dpi=200, output_folder=None, first_page=None, last_page=None, fmt='ppm', jpegopt=None, thread_count=1, userpw=None, use_cropbox=False, strict=False, transparent=False, single_file=False, output_file=<pdf2image.generators.ThreadSafeGenerator object at 0x10a8a1590>, poppler_path=None, grayscale=False, size=None, paths_only=False)>

# %%
convert_from_bytes(open('your_path/example.pdf').read())
# Out:
# 01.jpg
# 5de75c8f40860.png
# Ahern_S-lyubovyu-Rozi.506728.fb2.epub
# Application-Forms-For-2020-International-Admissions-3.pages*
# Application-forms 4.pages*
# Application-forms 5.pages*
# CSS 324 Introduction to Machine Learning Lecture 0.pptx.cpgz
# Forma-zayavki-ENG 2.xlsx
# Forma-zayavki-ENG.xlsx
# Forma-zayavki-ENG.xlsx 2.cpgz
# Forma-zayavki-ENG.xlsx 3.cpgz
# Forma-zayavki-ENG.xlsx.cpgz
# Freebie Template 1 - Car Repair and Doggie Daycare by June Parent.dms
# Gilbert_Est-molitsya-lyubit.156602.fb2.epub
# Group 2.png
# Group 6.jpg
# Group 7.jpg
# Group 8.jpg
# Logistic Regression Model (1).ipynb
# Path to store the CSV file\File name.csv
# RnnChatPrediction-master/
# Screen Recording 2020-04-01 at 21.07.56.mov
# Screen Recording 2020-04-01 at 21.30.10.mov
# Screen Recording 2020-04-01 at 21.31.39.mov
# Screen Recording 2020-04-01 at 21.32.22.mov
# Screen Recording 2020-04-01 at 21.32.57.mov
# Screen Recording 2020-04-01 at 21.33.39.mov
# Screen Recording 2020-04-01 at 21.37.40.mov
# Screen Recording 2020-04-01 at 21.38.19.mov
# Screen Recording 2020-04-01 at 21.40.47.mov
# Screen Recording 2020-04-01 at 21.42.14.mov
# Screen Shot 2019-12-05 at 14.07.20.png
# Screen Shot 2019-12-05 at 14.07.47.png
# Screen Shot 2019-12-05 at 14.07.52.png
# Screen Shot 2019-12-05 at 14.08.01.png
# Screen Shot 2019-12-05 at 14.08.06.png
# Screen Shot 2019-12-05 at 14.34.09.png
# Screen Shot 2019-12-05 at 14.38.15.png
# Screen Shot 2019-12-05 at 14.38.24.png
# Screen Shot 2019-12-05 at 14.38.28.png
# Screen Shot 2019-12-05 at 14.39.40.png
# Screen Shot 2019-12-05 at 14.41.14.png
# Screen Shot 2019-12-06 at 17.29.24.png
# Screen Shot 2019-12-06 at 17.31.19.png
# Screen Shot 2019-12-06 at 17.32.08.png
# Screen Shot 2019-12-07 at 15.38.02.png
# Screen Shot 2019-12-10 at 00.41.15.png
# Screen Shot 2019-12-11 at 11.39.45.png
# Screen Shot 2019-12-15 at 13.36.30.png
# Screen Shot 2019-12-18 at 18.24.55.png
# Screen Shot 2019-12-18 at 18.25.16.png
# Screen Shot 2019-12-18 at 18.25.45.png
# Screen Shot 2019-12-18 at 19.24.55.png
# Screen Shot 2019-12-18 at 21.21.10.png
# Screen Shot 2019-12-18 at 21.40.15.png
# Screen Shot 2019-12-18 at 21.46.28.png
# Screen Shot 2019-12-18 at 22.03.00.png
# Screen Shot 2020-01-09 at 14.36.31.png
# Screen Shot 2020-01-09 at 14.36.47.png
# September'2015.xlsx.cpgz
# September2015.xlsx
# TensorFlow-Object-Detection-API-Tutorial-Train-Multiple-Objects-Windows-10-master/
# Ulzhan-2.pdf
# Ulzhan.pdf
# UlzhanAkmurat_CV 2.pdf
# UlzhanAkmurat_CV.pdf
# Ulzhan_Akmurat.pdf
# Ulzhan_akmurat_UNIST.pdf
# Untitled.ipynb
# Untitled1.ipynb
# Untitled2.ipynb
# Untitled3.ipynb
# Untitled4.ipynb
# Untitled5.ipynb
# aaa.jpg
# aaa_cropped0.jpg
# bazel-1.1.0-installer-darwin-x86_64.sh*
# bazelisk/
# bazelisk-master.zip
# check0.png
# check_name0.png
# check_name1.png
# color3.jpg
# color4.jpg
# color6.jpg
# computer vision/
# cut image.ipynb
# cutting_image.mp4
# data.xlsx
# data1.csv
# data2.csv
# data3.csv
# dbzb/
# diplCropToPng/
# face_recognition/
# jaxart/
# list.csv
# m1.csv
# m2.csv
# m3.csv
# m4.csv
# m5.csv
# machine learmimg /
# nurse_parse_region.ipynb
# out.pdf
# out.txt
# pytesseract/
# recommender-systems-master/
# temp_1.png
# temp_2.png
# temp_4.png
# temp_8.png
# temp_only_text.png
# tensorflow/
# tensorflow-master.zip*
# tensorflow1/
# untitled folder/
# untitled folder 2/
# untitled folder 3/
# Пикины-Копбаева.docx
# Предварительный просмотр файла 11.jpg11.jpg111 KB.webloc

# %%
import os
import os.path
import pytesseract
import argparse
import cv2
import time
from pdf2image import convert_from_path
from PyPDF2 import PdfFileReader, PdfFileWriter
from pdf2image.exceptions import (
 PDFInfoNotInstalledError,
 PDFPageCountError,
 PDFSyntaxError
)
from PIL import Image

start_time = time.time()


def pdfToPng():
    path = 'diplCropToPng/pngFormat'
    path2 = 'diplCropToPng/Tesseract'
    try:
        os.mkdir(path)
        os.mkdir(path2)
    except OSError:
        print("Creation of the directory %s failed" % path)
    else:
        print("Successfully created the directory %s " % path)
    images = convert_from_path('diploma.pdf')

    for i, image in enumerate(images):
        fname = 'image'+str(i+1)+'.png'
        image.save('diplCropToPng/pngFormat/'+fname, "PNG")

# Crops the image and saves it as "new_filename"
def crop_image(img, crop_area, new_filename):
    cropped_image = img.crop(crop_area)
    cropped_image.save(new_filename)

        #image_name = '/Users/turginbaevamadina/PycharmProjects/diploma/diplCropToPng/image1.png'
def check():  # The x, y coordinates of the areas to be cropped. (left, upper, right, lower)
    for i in range(83):
        path = 'diplCropToPng/image' + str(i + 1)
        try:
            os.mkdir(path)
        except OSError:
            print("Creation of the directory %s failed" % path)
        else:
            print("Successfully created the directory %s " % path)


    for i in range(1):
        crop_areas = [(0, 0, 920, 276), (1000, 100, 1600,270), (0, 280, 1650, 380), (0, 370, 1650, 530), (0, 520, 1650, 560)
            , (0, 550, 1650, 750), (0, 740, 1650, 805), (0, 800, 1650, 1300), (0, 1290, 1650, 1410), (0, 1400, 1650, 1580)
            , (0, 1580, 1655, 1730), (0, 1730, 1650, 2080)]

        for i in range(83):
            image_name = 'diplCropToPng/pngFormat/image' + str(i+1) +'.png'
            img = Image.open(image_name)
            image_name2 = 'diplCropToPng/image' + str(i + 1) + '.png'

            # Loops through the "crop_areas" list and crops the image based on the coordinates in the list
            for i, crop_area in enumerate(crop_areas):
                ...
                #if (i == 0):
                #   filename = os.path.splitext(image_name)[0]
                #   ext = os.path.splitext(image_name)[1]
                #   new_filename = filename +'/tensorflow'+ '_name' + str(
                #       i) + ext  # tanserflow - name of the second folder
                #   crop_image(img, crop_area, new_filename)
                #if (i == 1):
                #    filename = os.path.splitext(image_name)[0]
                #   ext = os.path.splitext(image_name)[1]
                #   new_filename = filename + '/tensorflow'+ '_name' + str(
                #       i) + ext  # tanserflow - name of the second folder
                #   crop_image(img, crop_area, new_filename)
                if (i == 3):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        1) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 5):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        2) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 7):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        3) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 9):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        4) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 11):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        5) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)


def tesseract():
    #reader = PdfFileReader('/Users/turginbaevamadina/Downloads/diploma.pdf', 'r')
    #sum = reader.getNumPages()
    img_cv = cv2.imread(r'tensorflow_name2.png')

    # By default OpenCV stores images in BGR format and since pytesseract assumes RGB format,
    # we need to convert from BGR to RGB format/mode:
    img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
    print(pytesseract.image_to_string(img_rgb))
    # OR
    img_rgb = Image.frombytes('RGB', img_cv.shape[:2], img_cv, 'raw', 'BGR', 0, 0)
    print(pytesseract.image_to_string(img_rgb))



pdfToPng()
check()
#tesseract()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# Creation of the directory diplCropToPng/pngFormat failed
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path)
#     408             env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 409         proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     410
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1521                             err_msg += ': ' + repr(err_filename)
# -> 1522                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1523                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pdfinfo': 'pdfinfo'
#
# During handling of the above exception, another exception occurred:
#
# PDFInfoNotInstalledError                  Traceback (most recent call last)
# <ipython-input-75-0654b55d7fd6> in <module>
#     122
#     123
# --> 124 pdfToPng()
#     125 check()
#     126 #tesseract()
#
# <ipython-input-75-0654b55d7fd6> in pdfToPng()
#      27     else:
#      28         print("Successfully created the directory %s " % path)
# ---> 29     images = convert_from_path('diploma.pdf')
#      30
#      31     for i, image in enumerate(images):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pdf2image/pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only)
#      87         poppler_path = poppler_path.as_posix()
#      88
# ---> 89     page_count = pdfinfo_from_path(pdf_path, userpw, poppler_path=poppler_path)["Pages"]
#      90
#      91     # We start by getting the output format, the buffer processing function and if we need pdftocairo
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path)
#     429     except OSError:
#     430         raise PDFInfoNotInstalledError(
# --> 431             "Unable to get page count. Is poppler installed and in PATH?"
#     432         )
#     433     except ValueError:
#
# PDFInfoNotInstalledError: Unable to get page count. Is poppler installed and in PATH?

# %%
ls
# Out:
# diplCropToPng/ diploma.pdf

# %%
import pytesseract

# %%
ls
# Out:
# diplCropToPng/ diploma.pdf

# %%
import os
import os.path
import pytesseract
import argparse
import cv2
import time
from pdf2image import convert_from_path
from PyPDF2 import PdfFileReader, PdfFileWriter
from pdf2image.exceptions import (
 PDFInfoNotInstalledError,
 PDFPageCountError,
 PDFSyntaxError
)
from PIL import Image

start_time = time.time()


def pdfToPng():
    path = 'pngFormat'
    path2 = 'Tesseract'
    os.mkdir(path)
    os.mkdir(path2)
    images = convert_from_path('diploma.pdf')

    for i, image in enumerate(images):
        fname = 'image'+str(i+1)+'.png'
        image.save('pngFormat/'+fname, "PNG")

# Crops the image and saves it as "new_filename"
def crop_image(img, crop_area, new_filename):
    cropped_image = img.crop(crop_area)
    cropped_image.save(new_filename)

        #image_name = '/Users/turginbaevamadina/PycharmProjects/diploma/diplCropToPng/image1.png'
def check():  # The x, y coordinates of the areas to be cropped. (left, upper, right, lower)
    for i in range(83):
        path = '/Users/turginbaevamadina/PycharmProjects/diploma/diplCropToPng/image' + str(i + 1)
        try:
            os.mkdir(path)
        except OSError:
            print("Creation of the directory %s failed" % path)
        else:
            print("Successfully created the directory %s " % path)


    for i in range(1):
        crop_areas = [(0, 0, 920, 276), (1000, 100, 1600,270), (0, 280, 1650, 380), (0, 370, 1650, 530), (0, 520, 1650, 560)
            , (0, 550, 1650, 750), (0, 740, 1650, 805), (0, 800, 1650, 1300), (0, 1290, 1650, 1410), (0, 1400, 1650, 1580)
            , (0, 1580, 1655, 1730), (0, 1730, 1650, 2080)]

        for i in range(83):
            image_name = '/Users/turginbaevamadina/PycharmProjects/diploma/diplCropToPng/pngFormat/image' + str(i+1) +'.png'
            img = Image.open(image_name)
            image_name2 = '/Users/turginbaevamadina/PycharmProjects/diploma/diplCropToPng/image' + str(i + 1) + '.png'

            # Loops through the "crop_areas" list and crops the image based on the coordinates in the list
            for i, crop_area in enumerate(crop_areas):
                ...
                #if (i == 0):
                #   filename = os.path.splitext(image_name)[0]
                #   ext = os.path.splitext(image_name)[1]
                #   new_filename = filename +'/tensorflow'+ '_name' + str(
                #       i) + ext  # tanserflow - name of the second folder
                #   crop_image(img, crop_area, new_filename)
                #if (i == 1):
                #    filename = os.path.splitext(image_name)[0]
                #   ext = os.path.splitext(image_name)[1]
                #   new_filename = filename + '/tensorflow'+ '_name' + str(
                #       i) + ext  # tanserflow - name of the second folder
                #   crop_image(img, crop_area, new_filename)
                if (i == 3):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        1) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 5):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        2) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 7):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        3) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 9):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        4) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)
                if (i == 11):
                    filename = os.path.splitext(image_name2)[0]
                    ext = os.path.splitext(image_name2)[1]
                    new_filename = filename + '/tensorflow'+ '_name' + str(
                        5) + ext  # tanserflow - name of the second folder
                    crop_image(img, crop_area, new_filename)


def tesseract():
    #reader = PdfFileReader('/Users/turginbaevamadina/Downloads/diploma.pdf', 'r')
    #sum = reader.getNumPages()
    img_cv = cv2.imread(r'tensorflow_name2.png')

    # By default OpenCV stores images in BGR format and since pytesseract assumes RGB format,
    # we need to convert from BGR to RGB format/mode:
    img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
    print(pytesseract.image_to_string(img_rgb))
    # OR
    img_rgb = Image.frombytes('RGB', img_cv.shape[:2], img_cv, 'raw', 'BGR', 0, 0)
    print(pytesseract.image_to_string(img_rgb))



#pdfToPng()
#check()
#tesseract()
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# --- 0.0008540153503417969 seconds ---

# %%
def pdfToPng():
    path = 'pngFormat'
    path2 = 'Tesseract'
    os.mkdir(path)
    os.mkdir(path2)
    images = convert_from_path('diploma.pdf')

    for i, image in enumerate(images):
        fname = 'image'+str(i+1)+'.png'
        image.save('pngFormat/'+fname, "PNG")

# %%
pdfToPng()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path)
#     408             env["LD_LIBRARY_PATH"] = poppler_path + ":" + env.get("LD_LIBRARY_PATH", "")
# --> 409         proc = Popen(command, env=env, stdout=PIPE, stderr=PIPE)
#     410
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     774                                 errread, errwrite,
# --> 775                                 restore_signals, start_new_session)
#     776         except:
#
# ~/opt/anaconda3/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1521                             err_msg += ': ' + repr(err_filename)
# -> 1522                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1523                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'pdfinfo': 'pdfinfo'
#
# During handling of the above exception, another exception occurred:
#
# PDFInfoNotInstalledError                  Traceback (most recent call last)
# <ipython-input-91-80ba46120976> in <module>
# ----> 1 pdfToPng()
#
# <ipython-input-90-7cc9779fa43d> in pdfToPng()
#       4     os.mkdir(path)
#       5     os.mkdir(path2)
# ----> 6     images = convert_from_path('diploma.pdf')
#       7
#       8     for i, image in enumerate(images):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pdf2image/pdf2image.py in convert_from_path(pdf_path, dpi, output_folder, first_page, last_page, fmt, jpegopt, thread_count, userpw, use_cropbox, strict, transparent, single_file, output_file, poppler_path, grayscale, size, paths_only)
#      87         poppler_path = poppler_path.as_posix()
#      88
# ---> 89     page_count = pdfinfo_from_path(pdf_path, userpw, poppler_path=poppler_path)["Pages"]
#      90
#      91     # We start by getting the output format, the buffer processing function and if we need pdftocairo
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pdf2image/pdf2image.py in pdfinfo_from_path(pdf_path, userpw, poppler_path)
#     429     except OSError:
#     430         raise PDFInfoNotInstalledError(
# --> 431             "Unable to get page count. Is poppler installed and in PATH?"
#     432         )
#     433     except ValueError:
#
# PDFInfoNotInstalledError: Unable to get page count. Is poppler installed and in PATH?

# %%
from PyPDF2 import PdfFileWriter, PdfFileReader
from wand.image import Image

# %%
def pdfToPng():
    path = 'png'
    inputpdf = PdfFileReader(open("diploma.pdf", "rb"))

    for i in range(inputpdf.numPages):
        output = PdfFileWriter()
        output.addPage(inputpdf.getPage(i))
        with open("png/student%s.pdf" % i, "wb") as outputStream:
            output.write(outputStream)
        input_path = "png/student%s.pdf" % i
        output_name = "png/student%s.png" % i
        source = Image(filename=input_path, resolution=300, width=2200)
        images = source.sequence
        for i in range(len(images)):
            Image(images[0]).save(filename=output_name.format(i))
        image_name2 = output_name
        img_cv = cv2.imread(image_name2)
        img_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
        new =pytesseract.image_to_string(img_rgb)
        file1 = open("png/student_text%s.png" % i,"a")
        file1.write(new)
        file1.close()

# %%
pdfToPng()
